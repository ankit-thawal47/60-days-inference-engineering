# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit-thawal47/60-days-inference-engineering/blob/main/Day1/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
import numpy as np
from numpy import array

# %% [markdown]
# **What is tensor?**
#
# - 1D - Vector
# - 2D - Matrix
# - nD - Tensor

# %%
sample_data = array(
    [
        [[1,2], [2,3], [2,2]],
        [[3,4], [6,7], [2,2]],
        [[5,5], [7,7], [2,2]]
    ]
)

print(sample_data.shape)
# Out:
# (3, 3, 2)

# %% [markdown]
# **Tensor Operations**
#
# - Addition
# -
